# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import numpy as np
from sklearn.metrics import accuracy_score

# %%
X = pd.read_csv("data.csv", encoding="utf-8")
y = pd.read_csv("test_label.csv", encoding="utf-8")

df = X.merge(y)
df
# Out:
#          ID  age            job   marital  education default  balance housing  \
# 0     53608   32     management    single   tertiary      no    12569      no
# 1     51055   25       services    single  secondary      no      801      no
# 2     52573   46    blue-collar   married  secondary      no     1728     yes
# 3     50458   39     management  divorced  secondary      no       51      no
# 4     52272   31       services    single   tertiary      no     1626      no
# ...     ...  ...            ...       ...        ...     ...      ...     ...
# 4286  50332   47         admin.   married  secondary      no      520      no
# 4287  51293   33     technician   married  secondary      no      133      no
# 4288  54023   40         admin.   married  secondary      no     2574     yes
# 4289  53775   39    blue-collar   married  secondary      no     2467      no
# 4290  51945   46  self-employed   married    primary      no       49      no
#
#      loan    contact  day month  campaign  pdays  previous poutcome    y
# 0      no   cellular    1   jul         2    295         2  success  yes
# 1      no   cellular    5   jun         2     -1         0  unknown  yes
# 2      no    unknown   26   may         2     -1         0  unknown   no
# 3      no    unknown   17   jun         2     -1         0  unknown   no
# 4      no    unknown   31   jul         1     -1         0  unknown   no
# ...   ...        ...  ...   ...       ...    ...       ...      ...  ...
# 4286   no  telephone    9   feb         6     -1         0  unknown   no
# 4287   no   cellular   12   nov         2    192         1  success  yes
# 4288   no   cellular   20   nov         1     -1         0  unknown   no
# 4289   no   cellular   19   jul         2    276         3    other  yes
# 4290   no   cellular   27   aug         6     -1         0  unknown   no
#
# [4291 rows x 17 columns]

# %%
lc = LabelEncoder()
for col in df.columns:
    if df[col].dtype == 'O':
        df[col] = lc.fit_transform(df[col])
df
# Out:
#          ID  age  job  marital  education  default  balance  housing  loan  \
# 0     53608   32    4        2          2        0    12569        0     0
# 1     51055   25    7        2          1        0      801        0     0
# 2     52573   46    1        1          1        0     1728        1     0
# 3     50458   39    4        0          1        0       51        0     0
# 4     52272   31    7        2          2        0     1626        0     0
# ...     ...  ...  ...      ...        ...      ...      ...      ...   ...
# 4286  50332   47    0        1          1        0      520        0     0
# 4287  51293   33    9        1          1        0      133        0     0
# 4288  54023   40    0        1          1        0     2574        1     0
# 4289  53775   39    1        1          1        0     2467        0     0
# 4290  51945   46    6        1          0        0       49        0     0
#
#       contact  day  month  campaign  pdays  previous  poutcome  y
# 0           0    1      5         2    295         2         2  1
# 1           0    5      6         2     -1         0         3  1
# 2           2   26      8         2     -1         0         3  0
# 3           2   17      6         2     -1         0         3  0
# 4           2   31      5         1     -1         0         3  0
# ...       ...  ...    ...       ...    ...       ...       ... ..
# 4286        1    9      3         6     -1         0         3  0
# 4287        0   12      9         2    192         1         2  1
# 4288        0   20      9         1     -1         0         3  0
# 4289        0   19      5         2    276         3         1  1
# 4290        0   27      1         6     -1         0         3  0
#
# [4291 rows x 17 columns]

# %%
X = df.iloc[:,1:-1]
y = df.iloc[:,-1]

# %%
X_train, X_test, y_train, y_test = train_test_split(
      X, y, test_size=0.33, random_state=42)

# %%
X.dtypes
# Out:
# age          int64
# job          int32
# marital      int32
# education    int32
# default      int32
# balance      int64
# housing      int32
# loan         int32
# contact      int32
# day          int64
# month        int32
# campaign     int64
# pdays        int64
# previous     int64
# poutcome     int32
# dtype: object

# %%
dt = DecisionTreeClassifier(random_state=100)
dt.fit(X_test,y_test)
# Out:
# DecisionTreeClassifier(random_state=100)

# %%
preds = dt.predict(X_test)
accuracy_score(y_test, preds)
# Out:
# 1.0
